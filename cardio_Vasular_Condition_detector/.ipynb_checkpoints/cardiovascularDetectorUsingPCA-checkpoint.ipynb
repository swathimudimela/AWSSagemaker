# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cardio_df = pd.read_csv("cardio_train.csv",sep=';')

# %%
cardio_df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# # Perform Exploratory Data Analysis

# %%
# Age looks weired
# gender looks weired

# we dont need id so lets drop id
cardio_df = cardio_df.drop(columns = 'id')

# %%
cardio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  int64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 6.4 MB

# %%
# lets convert age from days into years
cardio_df['age'] = cardio_df['age']/365

# %%
cardio_df['age'].head()
# Out:
# 0    50.391781
# 1    55.419178
# 2    51.663014
# 3    48.282192
# 4    47.873973
# Name: age, dtype: float64

# %%
# lets see if there are any null values
cardio_df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
# No null values in the data frame

# %%
cardio_df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.339358      1.349571    164.359229     74.205690    128.817286
# std        6.759594      0.476838      8.210126     14.395757    154.011419
# min       29.583562      1.000000     55.000000     10.000000   -150.000000
# 25%       48.394521      1.000000    159.000000     65.000000    120.000000
# 50%       53.980822      1.000000    165.000000     72.000000    120.000000
# 75%       58.430137      2.000000    170.000000     82.000000    140.000000
# max       64.967123      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# std      188.472530      0.680250      0.572270      0.283484      0.225568
# min      -70.000000      1.000000      1.000000      0.000000      0.000000
# 25%       80.000000      1.000000      1.000000      0.000000      0.000000
# 50%       80.000000      1.000000      1.000000      0.000000      0.000000
# 75%       90.000000      2.000000      1.000000      0.000000      0.000000
# max    11000.000000      3.000000      3.000000      1.000000      1.000000
#
#              active        cardio
# count  70000.000000  70000.000000
# mean       0.803729      0.499700
# std        0.397179      0.500003
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000

# %%
cardio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  float64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(2), int64(10)
# memory usage: 6.4 MB

# %%
# details of the individuals older than 64 years
cardio_df[cardio_df['age']>64.8]
# Out:
#              age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 395    64.824658       2     160    78.0    140     90            1     1
# 643    64.802740       1     154    79.0    130     80            1     1
# 2936   64.808219       2     156    60.0    140     90            1     1
# 4295   64.849315       1     169    75.0    120     80            1     1
# 9787   64.838356       2     165    70.0    120     80            1     1
# 10422  64.816438       2     177   102.0    130     80            1     2
# 16439  64.821918       1     160    65.0    130     80            3     3
# 18062  64.863014       1     140    48.0    170    100            2     1
# 20931  64.904110       1     165    63.0    150     90            2     1
# 22229  64.838356       2     170    91.0    130     90            1     1
# 26469  64.843836       1     169    80.0    120     80            1     1
# 26627  64.805479       1     156    66.0    140     90            3     3
# 27209  64.843836       1     170    66.0    110     70            1     1
# 27847  64.819178       1     154    59.0    130     90            1     1
# 28545  64.843836       2     166    89.0    160    100            1     1
# 33789  64.849315       1     158    65.0    120     80            1     1
# 36603  64.895890       2     163    55.0    120     80            3     1
# 37677  64.887671       2     165    64.0    120     80            1     1
# 40099  64.871233       1     165    74.0    120     80            1     1
# 40672  64.813699       2     168    69.0    120     80            1     1
# 45514  64.841096       1     156    75.0    100     80            1     1
# 46063  64.838356       1     159    58.0    120     60            1     1
# 48563  64.810959       2     165    70.0    120     80            2     1
# 48648  64.810959       2     160    60.0    120     80            1     1
# 50714  64.909589       2     167    68.0    120     80            2     2
# 53176  64.821918       1     166    66.0    120     80            1     1
# 55533  64.854795       1     160    60.0    120     80            1     1
# 55990  64.841096       1     160    70.0    120     90            1     1
# 57191  64.967123       2     175    75.0    120     80            1     1
# 57853  64.863014       1     165    65.0    130     80            1     1
# 59745  64.813699       2     174    70.0    120     80            1     1
# 59784  64.857534       2     170    68.0    110     80            2     2
# 64617  64.857534       2     171    69.0    110     70            1     1
# 67316  64.808219       2     174    80.0    140     90            1     1
# 68005  64.934247       1     178    75.0    120     80            1     1
# 68729  64.849315       1     160    75.0    110     90            1     1
# 69142  64.868493       1     169    70.0    120     80            3     3
#
#        smoke  alco  active  cardio
# 395        0     0       1       0
# 643        0     0       1       0
# 2936       0     0       1       1
# 4295       0     0       1       0
# 9787       0     0       0       0
# 10422      0     0       1       0
# 16439      0     0       0       1
# 18062      0     0       1       1
# 20931      0     0       1       1
# 22229      0     0       1       0
# 26469      0     0       1       0
# 26627      0     0       0       1
# 27209      0     0       0       1
# 27847      0     0       1       0
# 28545      0     0       1       1
# 33789      0     0       1       1
# 36603      1     0       1       1
# 37677      0     0       1       1
# 40099      0     0       1       0
# 40672      0     0       1       0
# 45514      0     0       0       0
# 46063      0     0       1       1
# 48563      1     0       0       1
# 48648      0     0       1       0
# 50714      0     0       0       1
# 53176      0     0       0       0
# 55533      0     0       1       1
# 55990      0     1       1       0
# 57191      0     0       1       1
# 57853      0     0       1       1
# 59745      0     0       1       1
# 59784      0     0       0       1
# 64617      0     0       1       0
# 67316      0     0       1       1
# 68005      0     0       1       1
# 68729      0     0       1       1
# 69142      0     0       1       1

# %% [markdown]
# # Visualize Data set

# %%
cardio_df.hist(bins = 20, figsize=(20,20),color = 'r')
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'height'}>],
#        [<AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'ap_hi'}>,
#         <AxesSubplot:title={'center':'ap_lo'}>],
#        [<AxesSubplot:title={'center':'cholesterol'}>,
#         <AxesSubplot:title={'center':'gluc'}>,
#         <AxesSubplot:title={'center':'smoke'}>],
#        [<AxesSubplot:title={'center':'alco'}>,
#         <AxesSubplot:title={'center':'active'}>,
#         <AxesSubplot:title={'center':'cardio'}>]], dtype=object)

# %%
sns.pairplot(cardio_df)

# %%
corr_matrix = cardio_df.corr()
plt.figure(figsize=(16,16))
sns.heatmap(corr_matrix, annot = True)
# Out:
# <AxesSubplot:>

# %%
# there are few +ve correlerations

# %%
# create train and test data set
df_target = cardio_df['cardio']
df_final = cardio_df.drop(columns = 'cardio')

# %%
df_target.shape
# Out:
# (70000,)

# %%
df_final.shape
# Out:
# (70000, 11)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_final,df_target, test_size = 0.2)

# %%
X_train.shape
# Out:
# (56000, 11)

# %%
X_test.shape
# Out:
# (14000, 11)

# %% [markdown]
# # Train and test xgboost in local mode

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-win_amd64.whl (124.9 MB)
#      -------------------------------------- 124.9/124.9 MB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\swath\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\swath\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Collecting numpy
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# Installing collected packages: numpy, xgboost
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Successfully installed numpy-2.0.2 xgboost-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# tensorflow 2.6.0 requires h5py~=3.1.0, but you have h5py 3.7.0 which is incompatible.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 2.0.2 which is incompatible.
# tensorflow 2.6.0 requires six~=1.15.0, but you have six 1.17.0 which is incompatible.
# tensorflow 2.6.0 requires typing-extensions~=3.7.4, but you have typing-extensions 4.15.0 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 2.0.2 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.2 which is incompatible.

# %%
# we havent used any PCA yet. We just simply build simple classifier

# %%
from xgboost import XGBClassifier

model = XGBClassifier()

model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
predict = model.predict(X_test)

# %%
predict
# Out:
# array([0, 1, 1, ..., 0, 1, 1])

# %%
# asses performance on the trained data set as well
predict_train = model.predict(X_train)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train,predict_train)
plt.figure()
sns.heatmap(cm, annot = True)
# Out:
# <AxesSubplot:>

# %%
# if we see above confusion matrix we see false +ves and false -ves are high

# %%
# lets calculate precision score and f1 and recall, accuracy

from sklearn.metrics import precision_score,recall_score,f1_score,accuracy_score

print("Precision = {}".format(precision_score(y_train,predict_train)))
print("Recall = {}".format(recall_score(y_train,predict_train)))
print("f1 score = {}".format(f1_score(y_train,predict_train)))
print("accuracy = {}".format(accuracy_score(y_train,predict_train)))
# Out:
# Precision = 0.7914471887315151
# Recall = 0.7237048665620094
# f1 score = 0.7560616508563655
# accuracy = 0.7662678571428572

# %%
# Not that great but better than the random classifier

# %%
# now lets see the metrics for test data
from sklearn.metrics import confusion_matrix

cm_test = confusion_matrix(y_test,predict)
plt.figure()
sns.heatmap(cm_test,annot = True)
# Out:
# <AxesSubplot:>

# %%
# here the results are better
# lets see the other metrics
from sklearn.metrics import precision_score, recall_score,f1_score,accuracy_score
print("Precision : {}".format(precision_score(y_test,predict)))
print("Recall : {}".format(recall_score(y_test,predict)))
print("Accuracy :{}".format(accuracy_score(y_test,predict)))
print("F1 score :{}".format(f1_score(y_test,predict)))
# Out:
# Precision : 0.7539817535178599
# Recall : 0.7014818011796864
# Accuracy :0.7381428571428571
# F1 score :0.7267849157847668

# %%
# lets try to re train the model with some hyperparameter changes
xgb_model = XGBClassifier(learning_rate = 0.01, n_estimators = 500 , max_depth = 20)
xgb_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=20, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
predict = xgb_model.predict(X_test)

# %%
# lets see if there is any improvement
new_model_cm = confusion_matrix(y_test,predict)
sns.heatmap(new_model_cm,annot = True)
# Out:
# <AxesSubplot:>

# %%
# dont see much improvement
print("Precision : {}".format(precision_score(y_test,predict)))
print("Recall : {}".format(recall_score(y_test,predict)))
print("Accuracy :{}".format(accuracy_score(y_test,predict)))
print("F1 score :{}".format(f1_score(y_test,predict)))
# Out:
# Precision : 0.7206344456082597
# Recall : 0.6928499496475328
# Accuracy :0.7141428571428572
# F1 score :0.7064691213143611

# %%
# it actually dropped

# %%
# try to attempt to tune xgboost classifier using grid search

# %%
param_grid = {
                'gamma' : [0.5,1,5], # regularization Parameter
                'subsample':[0.6,0.8,1.0], #% of rows taken to build each tree
                'colsample_bytree' : [0.6,0.8,1.0], #num of columns used by eah tree
                'max_depth' : [3,4,5] # depth of each tree
}

# %%
# lets create a grid
from sklearn.model_selection import GridSearchCV

# lets create a new xgb model
xgb_model_2 = XGBClassifier(learning_rate = 0.01,n_estimators = 100, objective = "binary:logistic")
grid = GridSearchCV(xgb_model_2, param_grid,verbose = 4)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.736 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.730 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.729 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.725 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.6;, score=0.731 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.737 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.732 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.728 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.724 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=0.8;, score=0.731 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.737 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.731 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.728 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.724 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=3, subsample=1.0;, score=0.731 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.737 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.733 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.734 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.727 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.6;, score=0.733 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.738 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.733 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.733 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.727 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=0.8;, score=0.733 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.739 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.733 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.732 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.727 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=4, subsample=1.0;, score=0.733 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.738 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.735 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.734 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.730 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.6;, score=0.733 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.737 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.735 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.733 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.730 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=0.8;, score=0.733 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.737 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.735 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.732 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.730 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=0.5, max_depth=5, subsample=1.0;, score=0.733 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.736 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.730 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.729 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.725 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.6;, score=0.731 total time=   0.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.737 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.732 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.728 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.724 total time=   0.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=0.8;, score=0.731 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.737 total time=   0.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.731 total time=   0.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.728 total time=   0.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.724 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=3, subsample=1.0;, score=0.731 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.737 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.733 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.734 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.727 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.6;, score=0.733 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.738 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.733 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.733 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.727 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=0.8;, score=0.733 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.739 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.733 total time=   0.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.732 total time=   0.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.727 total time=   0.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=4, subsample=1.0;, score=0.733 total time=   0.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.738 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.735 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.734 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.730 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.6;, score=0.733 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.737 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.735 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.733 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.730 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample=0.8;, score=0.733 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, max_depth=5, subsample
total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=0.8;, score=0.725 total time=   0.1s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.729 total time=   0.1s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.731 total time=   0.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.718 total time=   0.1s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.718 total time=   0.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=3, subsample=1.0;, score=0.725 total time=   0.1s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.737 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.736 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.727 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.723 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.6;, score=0.731 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.737 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.735 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.727 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.722 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=0.8;, score=0.731 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.735 total time=   0.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.736 total time=   0.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.728 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.722 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=4, subsample=1.0;, score=0.730 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.738 total time=   0.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.735 total time=   0.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.729 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.728 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.6;, score=0.733 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.738 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.734 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.727 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.726 total time=   0.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=0.8;, score=0.733 total time=   0.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.737 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.733 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.727 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.726 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, max_depth=5, subsample=1.0;, score=0.733 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.732 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.732 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.719 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.718 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.6;, score=0.726 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.729 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.731 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.719 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.718 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=0.8;, score=0.725 total time=   0.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.729 total time=   0.1s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.731 total time=   0.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.718 total time=   0.1s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.718 total time=   0.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=3, subsample=1.0;, score=0.725 total time=   0.1s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.736 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.736 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.727 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.723 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.6;, score=0.731 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.737 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.735 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.727 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.722 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=0.8;, score=0.731 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.735 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.736 total time=   0.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.728 total time=   0.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.722 total time=   0.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=4, subsample=1.0;, score=0.730 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.738 total time=   0.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.735 total time=   0.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.729 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.727 total time=   0.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.6;, score=0.734 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.738 total time=   0.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.734 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.727 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.726 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=0.8;, score=0.733 total time=   0.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.737 total time=   0.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.734 total time=   0.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.727 total time=   0.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.725 total time=   0.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=5, max_depth=5, subsample=1.0;, score=0.733 total time=   0.2s
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=0.01, max_b...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=100,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [0.5, 1, 5], 'max_depth': [3, 4, 5],
#                          'subsample': [0.6, 0.8, 1.0]},
#              verbose=4)

# %%
predict_optim = grid.predict(X_test)

# %%
# lets calculate the metrics
print("Precision : {}".format(precision_score(y_test,predict_optim)))
print("Recall : {}".format(recall_score(y_test,predict_optim)))
print("Accuracy :{}".format(accuracy_score(y_test,predict_optim)))
print("F1 score :{}".format(f1_score(y_test,predict_optim)))
# Out:
# Precision : 0.759003649056005
# Recall : 0.6882462954970507
# Accuracy :0.7367142857142858
# F1 score :0.7218952768975403

# %%
# there is a minor improvement
